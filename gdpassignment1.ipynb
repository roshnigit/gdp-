# %% [markdown]
# # Part I-A:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
path="E:\study\data science pg diploma\gdp"
os.chdir(path)

# %%
# Remove the rows: '(% Growth over the previous year)' and 'GSDP - CURRENT PRICES (` in Crore)' for the year 2016-17.

# %%
df = pd.read_csv("data1a.csv")

# %%
df.loc[df.Duration!="2016-17"]
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
#Calculate the average growth of states over the duration 2013-14, 2014-15 and 2015-16 by taking the mean of
#the row '(% Growth over previous year)'.

# %%
newdf=df.iloc[7:10]

# %%
statesdata=newdf.iloc[:,1:]

# %%
meandf= newdf.mean()
meandfsort=meandf.sort_values(ascending=False)

# %%
meandfsort.plot(figsize=(20,10),kind='bar')

# %%
tnewdf=newdf.T

# %%
at=tnewdf[2:]

# %%
atmeaned = at.copy()
atmeaned.columns=['2013-14','2014-15','2015-16']
atmeaned['mean'] = atmeaned.mean( axis=1)

# %%
atmeaned.index.name="States"
atmeaned
# Out:
#                           2013-14 2014-15 2015-16       mean
# States
# Andhra Pradesh              12.85    13.4   15.85  14.033333
# Arunachal Pradesh           16.38   14.79   12.07  14.413333
# Assam                       13.31   11.45   13.19  12.650000
# Bihar                        12.3   17.92   10.59  13.603333
# Chhattisgarh                16.44   13.69   10.98  13.703333
# Goa                         -5.77   13.12   10.75   6.033333
# Gujarat                     11.47   10.82   11.09  11.126667
# Haryana                     15.45    9.18   10.91  11.846667
# Himachal Pradesh            14.42   10.14     NaN  12.280000
# Jammu & Kashmir             10.09     4.7   17.91  10.900000
# Jharkhand                    7.92   15.14   11.44  11.500000
# Karnataka                   18.24    12.7   11.42  14.120000
# Kerala                      12.79   13.11   11.85  12.583333
# Madhya Pradesh              14.91   10.11   12.86  12.626667
# ...

# %%
consistency=atmeaned.sort_values(by=['2015-16'],ascending=False)

# %%
consistency.plot(y=['2013-14','2014-15','2015-16'],figsize=(20,10), kind="bar")

# %%
curiosity= atmeaned.loc[['Kerala','All_India GDP'],:]
curiosity.plot(y=['2013-14','2014-15','2015-16'],figsize=(20,10), kind="bar")

# %%
df = pd.read_csv("data1a.csv")
df.set_index('Duration')
dft=df.T
gdp=dft.iloc[2:]
gdps=gdp.iloc[:-6,:]

# %%
gdpst=gdps.sort_values(by=[4],ascending=False)

gdpst1=gdpst.iloc[:,4]
gdpst2=gdpst1.dropna()
gdpst2
# Out:
# Tamil Nadu           1.21267e+06
# Uttar Pradesh         1.1538e+06
# Karnataka            1.02707e+06
# Gujarat                   994316
# Andhra Pradesh            609934
# Kerala                    588337
# Telangana                 575631
# Madhya Pradesh            543975
# Haryana                   485184
# Bihar                     413503
# Odisha                    341887
# Chhattisgarh              260776
# Jharkhand                 241955
# Assam                     224234
# Uttarakhand               184091
# Jammu & Kashmir           118387
# Goa                        45002
# Meghalaya                  26745
# Arunachal Pradesh          18784
# Sikkim                     16637
# Name: 4, dtype: object

# %%
gdpst2[0:5,]
# Out:
# Tamil Nadu         1.21267e+06
# Uttar Pradesh       1.1538e+06
# Karnataka          1.02707e+06
# Gujarat                 994316
# Andhra Pradesh          609934
# Name: 4, dtype: object

# %%
gdpst2[-5:]
# Out:
# Jammu & Kashmir      118387
# Goa                   45002
# Meghalaya             26745
# Arunachal Pradesh     18784
# Sikkim                16637
# Name: 4, dtype: object

# %%
ax= gdpst2.plot(figsize=(20,10), kind="bar")

# %%
import pandas as pd
import glob

path = r'E:\study\data science pg diploma\gdp\data1b' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename,encoding='ISO-8859-1')
    li.append(df)

frame = pd.concat(li, axis=1)
frame
data1bf=frame.loc[:,['Item','2014-15']]
data1bf2= data1bf.iloc[:,27:]
data1bf2.columns=['Items','Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar','Chhatisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand','Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland','Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttrakhand']

# %%
percapita_gdp= data1bf2.iloc[32,1:]

# %%
pcg = percapita_gdp.sort_values(ascending= False)

gdp_capita_plot=pcg.plot(figsize=(15,15),kind='bar')

# %%
#Identify the top-5 and the bottom-5 states based on GDP per capita.
pcg[0:5]
pcg[-5:]
# Out:
# Jharkhand     62091
# Assam         60621
# Manipur       58442
# Uttrakhand    49450
# Bihar         33954
# Name: 32, dtype: object

# %%
ratio=max(pcg)/min(pcg)
print(ratio)
# Out:
# 8.004741709371503

# %%
percentage= data1bf2.iloc[[6,10,26,30],:]
percentage.set_index('Items')
# Out:
#                               Andhra Pradesh  Arunachal Pradesh     Assam  \
# Items
# Primary                             16303716             716959   5326697
# Secondary                           10488884             287489   4033091
# Tertiary                            22032942             631844   9307109
# Gross State Domestic Product        52646842            1676119  19809800
#
#                                  Bihar  Chhatisgarh      Goa     Gujarat  \
# Items
# Primary                        8019997      6400817   312129  15887187.0
# Secondary                      5984896      8238886  1547536  33023538.0
# Tertiary                      22179969      7588778  1738217  30220377.0
# Gross State Domestic Product  37391988     23498180  4063307  89502727.0
#
#                                  Haryana  Himachal Pradesh  Jammu and Kashmir  \
# Items
# Primary                        8040424.0           1548366            1620326
# ...

# %%
pert=percentage.T
pertx=pert.iloc[1:,:]
pertx.columns=['Primary','Secondary','Tertiary','GSDP']
pertx.pct_change()
# Out:
#                      Primary  Secondary    Tertiary       GSDP
# Andhra Pradesh           NaN        NaN         NaN        NaN
# Arunachal Pradesh  -0.956025  -0.972591   -0.971323  -0.968163
# Assam               6.429570  13.028679   13.730074  10.818851
# Bihar               0.505623   0.483948    1.383121   0.887550
# Chhatisgarh        -0.201893   0.376613   -0.657854  -0.371572
# Goa                -0.951236  -0.812167   -0.770949  -0.827080
# Gujarat            49.899426  20.339431   16.385848  21.027065
# Haryana            -0.493905  -0.619622   -0.363788  -0.511230
# Himachal Pradesh   -0.807427  -0.672078   -0.785020  -0.761422
# Jammu and Kashmir   0.046475  -0.447428    0.358055  -0.037984
# Jharkhand           2.239073   1.742139    0.448946   1.162326
# Karnataka           1.299064   2.281983    5.207858   3.245774
# Kerala             -0.462185  -0.410769   -0.412291  -0.429367
# Madhya Pradesh      1.751241  -0.167783   -0.389449  -0.083689
# ...

# %%
pert=percentage.T
pertx=pert.iloc[1:,:]
pertx.columns=['Primary','Secondary','Tertiary','GSDP']
perc = pertx.copy()
perc['primaryper']= (perc['Primary'].divide(perc['GSDP']))*100
perc['secper']= (perc['Secondary']/perc['GSDP'])*100
perc['tertper']= (perc['Tertiary']/perc['GSDP'])*100
perc
# Out:
#                        Primary    Secondary     Tertiary         GSDP  \
# Andhra Pradesh        16303716     10488884     22032942     52646842
# Arunachal Pradesh       716959       287489       631844      1676119
# Assam                  5326697      4033091      9307109     19809800
# Bihar                  8019997      5984896     22179969     37391988
# Chhatisgarh            6400817      8238886      7588778     23498180
# Goa                     312129      1547536      1738217      4063307
# Gujarat            1.58872e+07  3.30235e+07  3.02204e+07  8.95027e+07
# Haryana            8.04042e+06  1.25614e+07  1.92266e+07  4.37462e+07
# Himachal Pradesh       1548366      4119162      4133326     10436879
# Jammu and Kashmir      1620326      2276132      5613282     10040446
# Jharkhand              5248354      6241471      8133341     21710718
# Karnataka             12066304     20484404     50490630     92178806
# ...

# %%
perc.plot(y=['primaryper','secper','tertper'], figsize=(20,10),kind="bar",stacked=True)

# %%
quant=pertx.loc[:,'GSDP']
pd.qcut(quant,[0,0.2,0.5,0.85,1])
# Out:
# Andhra Pradesh        (27847636.0, 88088563.0]
# Arunachal Pradesh     (1155932.999, 2651149.0]
# Assam                  (2651149.0, 27847636.0]
# Bihar                 (27847636.0, 88088563.0]
# Chhatisgarh            (2651149.0, 27847636.0]
# Goa                    (2651149.0, 27847636.0]
# Gujarat              (88088563.0, 179212165.0]
# Haryana               (27847636.0, 88088563.0]
# Himachal Pradesh       (2651149.0, 27847636.0]
# Jammu and Kashmir      (2651149.0, 27847636.0]
# Jharkhand              (2651149.0, 27847636.0]
# Karnataka            (88088563.0, 179212165.0]
# Kerala                (27847636.0, 88088563.0]
# Madhya Pradesh        (27847636.0, 88088563.0]
# Maharashtra          (88088563.0, 179212165.0]
# Manipur               (1155932.999, 2651149.0]
# Meghalaya             (1155932.999, 2651149.0]
# Mizoram               (1155932.999, 2651149.0]
# Nagaland              (1155932.999, 2651149.0]
# Odisha                (27847636.0, 88088563.0]
# ...

# %%
C4= pertx.loc[(pertx['GSDP']>1155932.999) & (pertx['GSDP']<=2651149.0)]
C3= pertx.loc[(pertx['GSDP']>2651149.0) & (pertx['GSDP']<=27847636.0)]
C2= pertx.loc[(pertx['GSDP']>27847636.0) & (pertx['GSDP']<=88088563.0)]
C1= pertx.loc[(pertx['GSDP']>88088563.0) & (pertx['GSDP']<=179212165.0)]

# %%
data1bfc=data1bf.iloc[[0,5,7,8,9,11,14,22,23,24,25],27:]
data1bfc.columns=['Items','Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar','Chhatisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand','Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland','Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand']

# %%
C1D= data1bfc.loc[:,['Items','Gujarat','Karnataka','Maharashtra','Tamil Nadu','Uttar Pradesh']]

C2D= data1bfc.loc[:,['Items','Andhra Pradesh','Bihar','Haryana','Kerala','Madhya Pradesh','Odisha','Punjab','Rajasthan','Telangana']]

C3D= data1bfc.loc[:,['Items','Assam','Chhatisgarh','Goa','Himachal','Jammu and Kashmir','Jharkhand','Tripura','Uttrakhand']]

C4D= data1bfc.loc[:,['Items','Arunachal Pradesh','Manipur','Meghalaya','Mizoram','Nagaland','Sikkim']]

C4D['Total']=C4D.sum(axis=1)
C3D['Total']=C3D.sum(axis=1)
C2D['Total']=C2D.sum(axis=1)
C1D['Total']=C1D.sum(axis=1)
C1D.set_index('Items', inplace=True)
C2D.set_index('Items', inplace=True)
C3D.set_index('Items', inplace=True)
C4D.set_index('Items', inplace=True)
C1D.sort_values(by='Total',ascending= False)
C2D.sort_values(by='Total',ascending= False)
C3D.sort_values(by='Total',ascending= False)
C4D.sort_values(by='Total',ascending= False)
C1D
# Out:
# C:\Users\rosh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                                        Gujarat  Karnataka  \
# Items
# Agriculture, forestry and fishing                   13769969.0   11219422
# Mining and quarrying                                 2117218.0     846882
# Manufacturing                                       24087538.0   12953843
# Electricity, gas, water supply & other utility ...   3409983.0    1425762
# Construction                                         5526017.0    6104799
# Trade, repair, hotels and restaurants               10178713.0    8991658
# ...

# %%
C1plot = C1D.plot.pie(x='Item',y='Total', autopct='%.1f%%',figsize=(15,15),textprops={'fontsize': 20},legend=0.25)
plt.title("C1 plot")
plt.show()

# %%
C2plot = C2D.plot.pie(x='Item',y='Total', autopct='%.1f%%',figsize=(15,15),textprops={'fontsize': 20},legend=0.25)
plt.title("C2 plot")
plt.show()

# %%
C3plot = C3D.plot.pie(x='Item',y='Total', autopct='%.1f%%',figsize=(15,15),textprops={'fontsize': 20},legend=0.25)
plt.title("C3 plot")
plt.show()

# %%
C4plot = C4D.plot.pie(x='Item',y='Total', autopct='%.1f%%',figsize=(15,15),textprops={'fontsize': 20},legend=0.25)
plt.title("C4 plot")
plt.show()

# %%
dropout=pd.read_csv("rs_session243_au570_1.1.csv")
dropout1415=dropout.loc[:,['Level of Education - State','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']]
dropstate= dropout1415.iloc[[1,2,3,4,6,10,11,12,13,14,15,16,17,19,20,21,22,23,24,25,27,28,29,30,31,32,33,34],:]
ds=dropstate.set_index('Level of Education - State')

# %%
dfb= data1bf2.T
dfgc=dfb[32]
mf1=pd.concat([ds,dfgc],axis=1,sort= True)
mf2=mf1.drop('Items')
mf3=mf2.rename(index=str,columns={32:"Per Capita GDP"})

# %%
mf3['Per Capita GDP'] = mf3['Per Capita GDP'].apply(np.float64)
mf3['log gdp']=np.log(mf3['Per Capita GDP'])

# %%
mf3g=mf3.iloc[:,[0,1,2,4]]

# %%
cur= mf3g.corr()
round(cur,4)
# Out:
#                            Primary - 2014-2015  Upper Primary - 2014-2015  \
# Primary - 2014-2015                     1.0000                     0.4352
# Upper Primary - 2014-2015               0.4352                     1.0000
# Secondary - 2014-2015                   0.1269                     0.5453
# log gdp                                -0.3551                    -0.4387
#
#                            Secondary - 2014-2015  log gdp
# Primary - 2014-2015                       0.1269  -0.3551
# Upper Primary - 2014-2015                 0.5453  -0.4387
# Secondary - 2014-2015                     1.0000  -0.4788
# log gdp                                  -0.4788   1.0000

# %%
# figure size
plt.figure(figsize=(10,8))

# heatmap
sns.heatmap(cur, cmap="YlGnBu", annot=True)
plt.show()

# %%
mf3gs=mf3g.sort_values(by='log gdp',ascending= False)
mf3gs.plot(y=['Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015','log gdp'], figsize=(20,10),kind="bar")

# %%
mf3gs
# Out:
#                    Primary - 2014-2015  Upper Primary - 2014-2015  \
# Goa                               0.20                       0.07
# Sikkim                            4.57                       1.57
# Haryana                           0.41                       5.81
# Kerala                             NaN                        NaN
# Uttar Pradesh                     7.08                       2.70
# Maharashtra                       0.55                       1.79
# Himachal Pradesh                  0.46                       0.87
# Tamil Nadu                        0.46                        NaN
# Karnataka                         2.32                       3.85
# Gujarat                           0.76                       6.41
# Telangana                         5.81                       2.30
# Punjab                            1.29                       3.22
# Arunachal Pradesh                10.89                       6.71
# ...
